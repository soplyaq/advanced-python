# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 2.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.9 MB 2.6 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.9 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.9 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.9 MB 2.8 MB/s eta 0:00:03
#    --------------- ------------------------ 3.9/9.9 MB 2.9 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.9 MB 3.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.9 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.9 MB 3.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/9.9 MB 3.3 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
import pandas as pd

data = {
    "Name": ["Samira", "Lili", "Lala", "Lulu", "Lolo"],
    "Age": [19, 21, 22, 20, 18],
    "Score": [67, 85, 90, 86, 92]
}

df = pd.DataFrame(data)
print("DataFrame:")
print (df)
# Out:
# DataFrame:
#      Name  Age  Score
# 0  Samira   19     67
# 1    Lili   21     85
# 2    Lala   22     90
# 3    Lulu   20     86
# 4    Lolo   18     92

# %%
print("First 3 rows:")
print(df.head(3))

print("\nSummary statistics:")
stats = df.describe().round(2)
print(stats)

average_score = df['Score'].mean()
print(f"\nAverage Score: {average_score:.2f}")
# Out:
# First 3 rows:
#      Name  Age  Score
# 0  Samira   19     67
# 1    Lili   21     85
# 2    Lala   22     90
#
# Summary statistics:
#          Age  Score
# count   5.00   5.00
# mean   20.00  84.00
# std     1.58   9.92
# min    18.00  67.00
# 25%    19.00  85.00
# 50%    20.00  86.00
# 75%    21.00  90.00
# max    22.00  92.00
#
# Average Score: 84.00

# %%
older_than_20 = df[df['Age'] > 20]
print("Students older than 20:")
print(older_than_20)

score_above_80 = df[df['Score'] > 80]
print("\nStudents with score above 80:")
print(score_above_80)
# Out:
# Students older than 20:
#    Name  Age  Score
# 1  Lili   21     85
# 2  Lala   22     90
#
# Students with score above 80:
#    Name  Age  Score
# 1  Lili   21     85
# 2  Lala   22     90
# 3  Lulu   20     86
# 4  Lolo   18     92
